# %% [markdown]
# # Amazon Sales Report Analysis
#
# This notebook contains a comprehensive analysis of Amazon sales data to extract actionable insights and support business decision-making. We'll analyze various aspects of the sales data including temporal patterns, product categories, fulfillment methods, geographical distribution, and customer behavior.
#
# ## Table of Contents
# 1. Data Loading and Initial Exploration
# 2. Data Cleaning and Preprocessing
# 3. Temporal Analysis
# 4. Product Category Analysis
# 5. Fulfillment Analysis
# 6. Geographic Analysis
# 7. Customer Behavior Analysis
# 8. Statistical Analysis and Correlations
# 9. Data Visualization Dashboard

# %%
# Import required libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
